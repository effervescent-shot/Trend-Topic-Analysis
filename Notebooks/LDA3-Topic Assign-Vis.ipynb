# %%
import os
import re
import sys
import numpy as np
import pandas as pd
import string
import re

import nltk
from nltk.stem import PorterStemmer
from nltk.tokenize import RegexpTokenizer
from nltk.stem.wordnet import WordNetLemmatizer
# NLTK Stop words
from nltk.corpus import stopwords

import gensim
from gensim import corpora, models
from gensim.models.coherencemodel import CoherenceModel
from gensim.test.utils import common_corpus, common_dictionary, datapath
from gensim.corpora import MmCorpus, Dictionary
from gensim.test.utils import get_tmpfile

from preprocessor.api import clean
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Plotting tools
import pyLDAvis
import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt
# %matplotlib inline

from utils import load_lda_datasets, load_test_dataset, load_model, get_stop_words, load_raw_datasets
# Out:
# LOADING RAW DATA TREND-TEXT, LENGTH:  1151
# LOADING CORPUS, LENGTH:  1151
# LOADING DICTIONARY, LENGTH:  54164
# LOADING DATASET, LENGTH:  1151

# %%
DATA_DIR = "../Data"
TWEETS_PATH = os.path.join(DATA_DIR, 'tweets')
TREND_PATH = os.path.join(DATA_DIR, 'trends')
SAVE_PATH = os.path.join(DATA_DIR, 'save')
STATS_PATH = os.path.join(DATA_DIR, 'stats')
TOPICS_PATH = os.path.join(DATA_DIR, 'topics')

# %% [markdown]
# # LOAD DATA STRUCTURES TEST DATA

# %%
dfs_train, trend_doc = load_raw_datasets()
stemmed_dataset, corpus, dictionary = load_lda_datasets()
# Out:
# LOADING RAW DATA TREND-TEXT, LENGTH:  1151
# LOADING CORPUS, LENGTH:  1151
# LOADING DICTIONARY, LENGTH:  54164
# LOADING DATASET, LENGTH:  1151

# %%
stop_words = get_stop_words()
test_doc, stemmed_test, corpus_test = load_test_dataset()

# %%
print(stemmed_test[0])
print(test_doc.loc[0].text)
print(corpus_test[:1])
# Out:
# ['antifa', 'one', 'act', 'like', 'fascist']
# rt  antifa are the ones acting like fascists the end
# [[(509, 1), (2241, 1), (2493, 1), (6103, 1), (6710, 1)]]

# %% [markdown]
# # LOAD MODEL AND TOPIC LIST

# %%
lda_model = load_model(10)

# %%
target_doc = pd.read_csv(os.path.join(DATA_DIR, 'categories'), header=0)
target_doc.head(3)
# Out:
#    Category ID  Category Name
# 0            0    Art & Design
# 1            1           Books
# 2            2        Business

# %%
k_list_10 = ['Fashion','Art & Design','Sports','Technology','Politics','News','Entertainment','Books','Sports','Music']
k_topics_classified = dict(zip(np.arange(10),k_list_10))
print(k_topics_classified)
# Out:
# {0: 'Fashion', 1: 'Art & Design', 2: 'Sports', 3: 'Technology', 4: 'Politics', 5: 'News', 6: 'Entertainment', 7: 'Books', 8: 'Sports', 9: 'Music'}

# %% [markdown]
# # VISUALIZE PRETRAINED MODEL

# %%
# Visualize the topics
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim.prepare(lda_model, corpus, dictionary)
vis
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 6     -0.030205 -0.100166       1        1  23.664310
# 7      0.038274 -0.052624       2        1  14.868079
# 8     -0.079809 -0.171959       3        1  12.190962
# 3      0.048705 -0.124334       4        1  11.341634
# 2     -0.132103  0.015438       5        1  10.664946
# 1     -0.144350  0.157854       6        1   6.589989
# 0      0.268078  0.073132       7        1   5.800333
# 4     -0.102727  0.219813       8        1   5.638982
# 9     -0.044527 -0.099405       9        1   5.553953
# 5      0.178663  0.082252      10        1   3.686820, topic_info=          Term          Freq         Total Category  logprob  loglift
# 30458  michael  44838.000000  44838.000000  Default  30.0000  30.0000
# 1690     amber  26569.000000  26569.000000  Default  29.0000  29.0000
# 33138     nike  16484.000000  16484.000000  Default  28.0000  28.0000
# 2154      anna  19261.000000  19261.000000  Default  27.0000  27.0000
# 19892     hall  11420.000000  11420.000000  Default  26.0000  26.0000
# ...        ...           ...           ...      ...      ...      ...
# 52793    women    878.927368   7087.793457  Topic10  -5.1991   1.2130
# 27425     like   1016.930786  30715.845703  Topic10  -5.0533  -0.1076
# 52914     work    883.500488   9401.908203  Topic10  -5.1940   0.9356
# 27648    littl    833.913391  10826.387695  Topic10  -5.2517   0.7368
# 13147     dont    821.865356  17998.089844  Topic10  -5.2663   0.2140
#
# [657 rows x 6 columns], token_table=       Topic      Freq         Term
# term
# 23         9  0.984128       aaaand
# 109        6  0.999632         abbo
# 196        8  0.990436      abolish
# 256        6  0.998991        abuja
# 321        5  0.998429  accordingli
# ...      ...       ...          ...
# 53941      9  0.959098         zaha
# 53951      1  0.998570        zaira
# 54015      7  0.400185      zendaya
# 54015     10  0.599215      zendaya
# 54138      4  0.998911   zuckerberg
#
# [1983 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[7, 8, 9, 4, 3, 2, 1, 5, 10, 6])

# %%
def format_topics_sentences(ldamodel=lda_model, corpus=corpus, texts=trend_doc.text):
    # Init output
    sent_topics_df = pd.DataFrame()

    # Get main topic in each document
    for i, row in enumerate(ldamodel[corpus]):
        row = sorted(row[0], key=lambda x: (x[1]), reverse=True)

        # Get the Dominant topic, Perc Contribution and Keywords for each document
        for j, (topic_num, prop_topic) in enumerate(row):
            if j == 0:  # => dominant topic
                wp = ldamodel.show_topic(topic_num)
                topic_keywords = ", ".join([word for word, prop in wp])
                sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
            else:
                break
    sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']

    # Add original text to the end of the output
    contents = pd.Series(texts)
    sent_topics_df = pd.concat([sent_topics_df, contents], axis=1)
    return(sent_topics_df)


df_topic_sents_keywords = format_topics_sentences()

# %%
# Format
df_dominant_topic = df_topic_sents_keywords.reset_index()
df_dominant_topic.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']
df_dominant_topic['Dominant_Topic'] = df_dominant_topic['Dominant_Topic'].map(lambda x: k_topics_classified[x])
# Show
df_dominant_topic.head(10)
# Out:
#    Document_No Dominant_Topic  Topic_Perc_Contrib  \
# 0            0  Entertainment              0.8690
# 1            1         Sports              0.6377
# 2            2  Entertainment              0.4832
# 3            3  Entertainment              0.7670
# 4            4  Entertainment              0.6680
# 5            5  Entertainment              0.6129
# 6            6     Technology              0.3849
# 7            7  Entertainment              0.4424
# 8            8         Sports              0.3893
# 9            9           News              0.7373
#
#                                             Keywords  \
# 0  venu, william, love, happi, like, gauff, time,...
# 1  warrior, kawhi, sign, laker, knick, net, deal,...
# 2  venu, william, love, happi, like, gauff, time,...
# 3  venu, william, love, happi, like, gauff, time,...
# 4  venu, william, love, happi, like, gauff, time,...
# 5  venu, william, love, happi, like, gauff, time,...
# 6  whatsapp, yix, kyungsoo, instagram, light, twi...
# 7  venu, william, love, happi, like, gauff, time,...
# 8  warrior, kawhi, sign, laker, knick, net, deal,...
# 9  taylor, swift, scooter, justin, support, biebe...
#
#                                                 Text
# 0  rt  is that yo sandwich,rt  video of when pick...
# 1  rt  an achilles for a jersey the guilt is real...
# 2  its sad how an average player like acua plays ...
# 3  from the  mercedesamg a amp cla leaked,rt  som...
# 4  rt  aew fyter fest recap  highlights part  han...
# 5  day  afghanistan vs westindies  to win correct...
# 6  rt   the reigning medallist and one of s revel...
# 7  rt  tj hockenson is rated one of the best rook...
# 8  southern daily echo saints confirm first team ...
# 9  rt  tts      borrell  christine lagarde  https...

# %%
trend_doc_topic = pd.concat([trend_doc, df_dominant_topic[['Dominant_Topic']]], axis=1)
trend_doc_topic.head(5)
# Out:
#                 trend                                               text  \
# 0           acefamily  rt  is that yo sandwich,rt  video of when pick...
# 1            achilles  rt  an achilles for a jersey the guilt is real...
# 2               acuña  its sad how an average player like acua plays ...
# 3  adviceforateenager  from the  mercedesamg a amp cla leaked,rt  som...
# 4        aewfyterfest  rt  aew fyter fest recap  highlights part  han...
#
#   Dominant_Topic
# 0  Entertainment
# 1         Sports
# 2  Entertainment
# 3  Entertainment
# 4  Entertainment

# %% [markdown]
# # VISUALIZATION

# %%
dfs_train.head(5)
# Out:
#             author_id                   id  \
# 0          3244519976  1146083229075685377
# 1          2232937624  1146434208438657024
# 2  800669560181387265  1146451136645357568
# 3  951756622426144768  1145798976899309569
# 4          3140403385  1146055852849131520
#
#                                                 text        trend trend_date
# 0    rt  the average height of the sixers lineup is        sixers 2019-07-01
# 1  rt  live feed of most people not yet realizing...  twitter dms 2019-07-03
# 2                                          now down        nzveng 2019-07-03
# 3  rt  time for williamson being spoken in the sa...   dhoniatcwc 2019-06-30
# 4  finals results come out tmr but im more worrie...      michael 2019-07-03

# %%
joined = pd.merge(trend_doc_topic[['trend','Dominant_Topic']],dfs_train, left_on='trend', right_on='trend')
joined
# Out:
#                 trend Dominant_Topic            author_id  \
# 0           acefamily  Entertainment           1486824241
# 1           acefamily  Entertainment   740225179318509568
# 2           acefamily  Entertainment           4727708973
# 3           acefamily  Entertainment   999371881714077696
# 4            achilles         Sports           1631550686
# ...               ...            ...                  ...
# 430010   우리대장윤두준생일축하해  Entertainment   999646206912479234
# 430011            위버스     Technology   821285006676893696
# 430012  음악곡으로취향을드러내보자  Entertainment   931876456732401664
# 430013  음악곡으로취향을드러내보자  Entertainment  1059434566950121473
# 430014  음악곡으로취향을드러내보자  Entertainment  1137513692969312257
#
#                          id  \
# 0       1145810083390971904
# 1       1145613529929539584
# 2       1145682018698768386
# 3       1145726516099026949
# 4       1145802563016712192
# ...                     ...
# 430010  1146539628066795520
# 430011  1145854530438889473
# 430012  1145958209435271168
# 430013  1145839514851536898
# 430014  1145883647314026496
#
#                                                      text trend_date
# 0                                 rt  is that yo sandwich 2019-06-30
# 1       rt  video of when picked me up you can hear ou... 2019-06-30
# 2       rt  thank you for everything proof that he is ... 2019-06-30
# 3       here is our basketball charity event video you... 2019-06-30
# 4          rt  an achilles for a jersey the guilt is real 2019-07-01
# ...                                                   ...        ...
# 430010  rt  more than my birthday our album is more im... 2019-07-03
# 430011  rt  weverse is  in korean  means upper and  me... 2019-07-01
# 430012  rt  billie eilish  bad guy luis fonsi  despaci... 2019-07-02
# 430013   acdc  back in black  acdc  shoot to thrill  a... 2019-07-02
# 430014     lost blue lights  jorja smith but maybe  ma... 2019-07-02
#
# [430015 rows x 6 columns]

# %%
topic_by_time = joined[['Dominant_Topic','trend_date','trend']].groupby(['trend_date','Dominant_Topic'])\
                ['trend'].apply(set).reset_index()

topic_by_time['Frequency'] = topic_by_time['trend'].apply(lambda x: len(x))
plot_df = topic_by_time.groupby(['trend_date']).apply(lambda x: x.nlargest(3, 'Frequency')).reset_index(drop=True)
plot_df
# Out:
#    trend_date Dominant_Topic  \
# 0  2019-06-30  Entertainment
# 1  2019-06-30         Sports
# 2  2019-06-30          Music
# 3  2019-07-01  Entertainment
# 4  2019-07-01         Sports
# 5  2019-07-01     Technology
# 6  2019-07-02  Entertainment
# 7  2019-07-02          Music
# 8  2019-07-02         Sports
# 9  2019-07-03  Entertainment
# 10 2019-07-03          Music
# 11 2019-07-03         Sports
# 12 2019-07-04  Entertainment
# 13 2019-07-04         Sports
# 14 2019-07-04        Fashion
#
#                                                 trend  Frequency
# 0   {kedar, hiltonbetyaşında, miorgulloes, eurosub...        197
# 1   {north korea, asapnatinto, kenny omega, middle...         46
# 2   {leclerc, vettel, ben stokes, the cure, versta...         17
# 3   {keepsmilingyunhyeong, clawstnt, prialcantaran...        162
# 4   {klay, rip tyler, iguodala, brooklyn, survivor...         91
# 5   {여자친구열대야로여름을열때야, kinpri, buenlunes, my ot, exo...         19
# 6   {baba rahman, keepsmilingyunhyeong, jordan aye...        167
# 7   {houghton, rapinoe, jonathan pearce, millie br...         40
# 8   {coys, pablo sarabia, smibukabukaanblbi, borre...         30
# 9   {ลับลวงใจep, snappingstwin, tldenttverilir, ec...        132
# 10  {messi, rapinoe, alex sandro, alisson, nzveng,...         31
# 11  {boycotttrumpthofjuly, تحذيرالسفارهالسعوديهبتر...         29
# 12  {pinkcarpetmtvmiaw, mgamavote, اخرصورهفيجوالك,...        135
# 13  {boycotttrumpthofjuly, justin amash, lampard, ...         26
# 14  {chilevsperú, peru, prince eric, little mermai...         14

# %%
import plotly.express as px

fig = px.bar(plot_df, x="trend_date", y="Frequency", color='Dominant_Topic', barmode='group',
             height=400, width=900 )
fig.show()
# Out:
# <div>
#
#
#             <div id="5b61a0fc-99c1-42a1-aaaf-d4df552861b3" class="plotly-graph-div" style="height:400px; width:900px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5b61a0fc-99c1-42a1-aaaf-d4df552861b3")) {
#                     Plotly.newPlot(
#                         '5b61a0fc-99c1-42a1-aaaf-d4df552861b3',
#                         [{"alignmentgroup": "True", "hovertemplate": "Dominant_Topic=Entertainment<br>trend_date=%{x}<br>Frequency=%{y}<extra></extra>", "legendgroup": "Entertainment", "marker": {"color": "#636efa"}, "name": "Entertainment", "offsetgroup": "Entertainment", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["2019-06-30T00:00:00", "2019-07-01T00:00:00", "2019-07-02T00:00:00", "2019-07-03T00:00:00", "2019-07-04T00:00:00"], "xaxis": "x", "y": [197, 162, 167, 132, 135], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Dominant_Topic=Sports<br>trend_date=%{x}<br>Frequency=%{y}<extra></extra>", "legendgroup": "Sports", "marker": {"color": "#EF553B"}, "name": "Sports", "offsetgroup": "Sports", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["2019-06-30T00:00:00", "2019-07-01T00:00:00", "2019-07-02T00:00:00", "2019-07-03T00:00:00", "2019-07-04T00:00:00"], "xaxis": "x", "y": [46, 91, 30, 29, 26], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Dominant_Topic=Music<br>trend_date=%{x}<br>Frequency=%{y}<extra></extra>", "legendgroup": "Music", "marker": {"color": "#00cc96"}, "name": "Music", "offsetgroup": "Music", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["2019-06-30T00:00:00", "2019-07-02T00:00:00", "2019-07-03T00:00:00"], "xaxis": "x", "y": [17, 40, 31], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Dominant_Topic=Technology<br>trend_date=%{x}<br>Frequency=%{y}<extra></extra>", "legendgroup": "Technology", "marker": {"color": "#ab63fa"}, "name": "Technology", "offsetgroup": "Technology", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["2019-07-01T00:00:00"], "xaxis": "x", "y": [19], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Dominant_Topic=Fashion<br>trend_date=%{x}<br>Frequency=%{y}<extra></extra>", "legendgroup": "Fashion", "marker": {"color": "#FFA15A"}, "name": "Fashion", "offsetgroup": "Fashion", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["2019-07-04T00:00:00"], "xaxis": "x", "y": [14], "yaxis": "y"}],
#                         {"barmode": "group", "height": 400, "legend": {"title": {"text": "Dominant_Topic"}, "tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marke ...

# %%
topic_by_author = joined[['Dominant_Topic','trend_date', 'trend','author_id']].groupby(['trend_date','Dominant_Topic']).\
                    agg({'author_id': [set], 'trend':[set]}).reset_index()
topic_by_author.columns = ['trend_date', 'Dominant_Topic','author_id','trend']
topic_by_author['Frequency'] = topic_by_author['author_id'].apply(lambda x: len(x))
topic_by_author.drop(['author_id'], axis=1, inplace=True)

plot_df2 = topic_by_author.groupby(['trend_date']).apply(lambda x: x.nlargest(3, 'Frequency')).reset_index(drop=True)
plot_df2
# Out:
#    trend_date Dominant_Topic  \
# 0  2019-06-30  Entertainment
# 1  2019-06-30         Sports
# 2  2019-06-30   Art & Design
# 3  2019-07-01  Entertainment
# 4  2019-07-01         Sports
# 5  2019-07-01     Technology
# 6  2019-07-02  Entertainment
# 7  2019-07-02          Books
# 8  2019-07-02     Technology
# 9  2019-07-03  Entertainment
# 10 2019-07-03          Books
# 11 2019-07-03         Sports
# 12 2019-07-04  Entertainment
# 13 2019-07-04         Sports
# 14 2019-07-04     Technology
#
#                                                 trend  Frequency
# 0   {kedar, hiltonbetyaşında, miorgulloes, eurosub...       8939
# 1   {north korea, asapnatinto, kenny omega, middle...       8933
# 2     {مليونهيونيو, antifa, andy ngo, stepdownpastor}       5096
# 3   {keepsmilingyunhyeong, clawstnt, prialcantaran...      26569
# 4   {klay, rip tyler, iguodala, brooklyn, survivor...      23559
# 5   {여자친구열대야로여름을열때야, kinpri, buenlunes, my ot, exo...      21652
# 6   {baba rahman, keepsmilingyunhyeong, jordan aye...      30795
# 7   {dubas, kerfoot, michael, ovie, sylvia mulinge...      18312
# 8   {ddos, marmitinhasdojustin, taokaenoixsehun, b...      12841
# 9   {ลับลวงใจep, snappingstwin, tldenttverilir, ec...      14349
# 10  {carsamba, michael, temmuz, jourdan, poramor, ...      13344
# 11  {boycotttrumpthofjuly, تحذيرالسفارهالسعوديهبتر...      10834
# 12  {pinkcarpetmtvmiaw, mgamavote, اخرصورهفيجوالك,...      11222
# 13  {boycotttrumpthofjuly, justin amash, lampard, ...       9260
# 14  {mark zuckerberg, فيايمدينهمولود, mv teaser, m...       7978

# %%
import plotly.express as px

fig = px.bar(plot_df2, x="trend_date", y="Frequency", color='Dominant_Topic', barmode='group',
             height=400, width=900 )
fig.show()
# Out:
# <div>
#
#
#             <div id="b26bc6b9-a4f4-4ca3-904b-aee7e9689257" class="plotly-graph-div" style="height:400px; width:900px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b26bc6b9-a4f4-4ca3-904b-aee7e9689257")) {
#                     Plotly.newPlot(
#                         'b26bc6b9-a4f4-4ca3-904b-aee7e9689257',
#                         [{"alignmentgroup": "True", "hovertemplate": "Dominant_Topic=Entertainment<br>trend_date=%{x}<br>Frequency=%{y}<extra></extra>", "legendgroup": "Entertainment", "marker": {"color": "#636efa"}, "name": "Entertainment", "offsetgroup": "Entertainment", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["2019-06-30T00:00:00", "2019-07-01T00:00:00", "2019-07-02T00:00:00", "2019-07-03T00:00:00", "2019-07-04T00:00:00"], "xaxis": "x", "y": [8939, 26569, 30795, 14349, 11222], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Dominant_Topic=Sports<br>trend_date=%{x}<br>Frequency=%{y}<extra></extra>", "legendgroup": "Sports", "marker": {"color": "#EF553B"}, "name": "Sports", "offsetgroup": "Sports", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["2019-06-30T00:00:00", "2019-07-01T00:00:00", "2019-07-03T00:00:00", "2019-07-04T00:00:00"], "xaxis": "x", "y": [8933, 23559, 10834, 9260], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Dominant_Topic=Art & Design<br>trend_date=%{x}<br>Frequency=%{y}<extra></extra>", "legendgroup": "Art & Design", "marker": {"color": "#00cc96"}, "name": "Art & Design", "offsetgroup": "Art & Design", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["2019-06-30T00:00:00"], "xaxis": "x", "y": [5096], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Dominant_Topic=Technology<br>trend_date=%{x}<br>Frequency=%{y}<extra></extra>", "legendgroup": "Technology", "marker": {"color": "#ab63fa"}, "name": "Technology", "offsetgroup": "Technology", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["2019-07-01T00:00:00", "2019-07-02T00:00:00", "2019-07-04T00:00:00"], "xaxis": "x", "y": [21652, 12841, 7978], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Dominant_Topic=Books<br>trend_date=%{x}<br>Frequency=%{y}<extra></extra>", "legendgroup": "Books", "marker": {"color": "#FFA15A"}, "name": "Books", "offsetgroup": "Books", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["2019-07-02T00:00:00", "2019-07-03T00:00:00"], "xaxis": "x", "y": [18312, 13344], "yaxis": "y"}],
#                         {"barmode": "group", "height": 400, "legend": {"title": {"text": "Dominant_Topic"}, "tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marke ...
